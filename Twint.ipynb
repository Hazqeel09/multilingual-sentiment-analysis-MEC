# %%
import twint
import nest_asyncio

# %%
nest_asyncio.apply()

# Configure
c = twint.Config()
c.Username = "_hazqeel"
c.Store_object = True
c.Retweets = True

# Run
twint.run.Search(c)
# Out:
# 1318846424839114752 2020-10-21 17:27:45 +0800 <_hazqeel> @realzique Hmmmm, nampak location tapi tak nampak kat web. Camne aku nak scrapeeee
# 1318503796599746560 2020-10-20 18:46:16 +0800 <_hazqeel> @nursyaanis Bagus2
# 1318497190554128386 2020-10-20 18:20:01 +0800 <_hazqeel> @nursyaanis *setan
# 1315490170502668293 2020-10-12 11:11:11 +0800 <_hazqeel> @sggwans Nak ryujin gak, sobs
# 1314700631819513856 2020-10-10 06:53:51 +0800 <_hazqeel> @z4rule Maka berdoalah
# 1314230245679984640 2020-10-08 23:44:42 +0800 <_hazqeel> @z4rule @luxconduct Thanks awak
# 1284134145443037187 2020-07-17 22:33:32 +0800 <_hazqeel> @sggwans Ish
# 1264881200708988928 2020-05-25 19:29:13 +0800 <_hazqeel> @sggwans Tak tahu nak reply apa, hnsss hnsss
# 1261801990377443329 2020-05-17 07:33:32 +0800 <_hazqeel> @sggwans Been asking that for years
# 1260607559922118656 2020-05-14 00:27:17 +0800 <_hazqeel> @sggwans Mesti sedih bukan orang kelantan
# ...

# %%
twint.run.Followers(c)
target_followers = twint.output.users_list
# Out:
# CRITICAL:root:twint.feed:Follow:IndexError
# nursyaanis
# sggwans
# syahmirozik_
# sharulerfan
# MirTheSleazebag
# tihahahahampeh
# Iam_syahmin
# realzique
# naimhusaini7
# IrfanSauti_
# z4rule
# wixard10
# CRITICAL:root:twint.feed:Follow:IndexError

# %%
twint.output.tweets_object
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-1a8d4f11d7a1> in <module>
# ----> 1 twint.output.tweets_object
#
# AttributeError: module 'twint.output' has no attribute 'tweets_object'

# %%
twint.output
# Out:
# <module 'twint.output' from 'C:\\Users\\User.DESKTOP-F2C5SG4\\AppData\\Roaming\\Python\\Python38\\site-packages\\twint\\output.py'>

# %%
nest_asyncio.apply()

# Configure
c = twint.Config()
c.Username = "realzique"
c.Limit = 100
c.Retweets = True
c.Store_csv = True
c.Output = "zique_out.csv"
#running search
twint.run.Search(c)
# Out:
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# CRITICAL:root:twint.output:_output:CSV:Error:'Config' object has no attribute 'Tabs'
# ...
